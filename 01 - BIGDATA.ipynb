# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/UDEA-Esp-Analitica-y-Ciencia-de-Datos/EACD-03-BIGDATA/master/init.py
import init; init.init(force_download=False); 
from IPython.display import Image
# Out:
# replicating local resources

# %%
Image("local/imgs/udea-datascience.png")

# %% [markdown]
# #**BIGDATA**

# %% [markdown]
# #**Introducción**

# %% [markdown]
# **Qué es Big Data?**
#
# "Conjunto de **técnicas** que permiten **analizar, procesar y gestionar** conjuntos de datos **extremadamente grandes** que pueden ser analizados informáticamente para **revelar patrones, tendencias y asociaciones**, especialmente en relación con la conducta humana y las interacciones con los usuarios"
#
# Tomado de: https://dej.rae.es/lema/big-data

# %% [markdown]
# **Las Vs del Big Data**
#
# Las características que debe tener un proyecto para que sea considerado como Big Data se definen en función de palabras que empiezan por la letra V.
# Las Vs principales del Big Data son:
# * Volumen
# * Velocidad
# * Variedad

# %%
Image("local/imgs/bigData3.png")

# %% [markdown]
# Con el tiempo se han ido adicionando otras características, al punto que hoy se puede hablar de alrededor de 10 características

# %%
Image("local/imgs/bigData10.png")

# %% [markdown]
# **¿De dónde salen tantos datos?**
#
# Existen múltiples fuentes de generación de datos que han dado origen a proyectos de Big Data.
#
# Vamos a resaltar las siguientes fuentes de generación de datos:
# * Redes sociales y aplicaciones
# * IoT

# %% [markdown]
# ##**Redes sociales y aplicaciones**
#
# Con la masificación del Internet y la acogida de los dispositivos móviles, entre otros factores, aparecen una gran cantidad de aplicaciones y redes sociales que generan grandes volúmenes de datos con una velocidad de generación impresionante.
#
# ¿Te has preguntado qué pasa en un minuto en Internet?

# %%
Image("local/imgs/minutoInternet2019.png")

# %% [markdown]
# ##**Internet de las cosas (IoT)**
#
# Tres letras que lo están cambiando todo
#
# **Antes:** Los seres humanos eran quienes capturaban la información y la subían a internet
#
# **Ahora:** Las cosas (dispositivos instalados sobre cualquier objeto físico, con capacidad de medición y comunicación) se encargan de capturar y subir la información a internet.
#
# La siguiente imagen presenta una arquitectura general para IoT

# %%
Image("local/imgs/iot.png")

# %% [markdown]
# #**Arquitecturas de Big Data**
#
# Los nuevos desafíos que trae consigo Big Data han generado evolución en diversas áreas, entre ellas, los sismas de información.
#
# Veníamos acostumbrados a trabajar en sistemas centralizados en los cuales tanto almacenamiento como procesamiento dependían de una sola máquina.
#
# Big Data propone una arquitectura diferente en la que pasamos de sistemas centralizados a sistemas de almacenamiento y procesamiento distribuidos

# %%
Image("local/imgs/arquitectura.png")

# %% [markdown]
# Ese cambio de arquitectura trae consigo la necesidad de que los sistemas sean escalables, y esa escalabilidad se realiza de manera horizontal de modo que si se requiere mayor procesamiento o almacenamiento basta con adicionar más máquinas.

# %% [markdown]
# #**Datos**
#
# Los datos son la materia prima del Big Data y pueden entenderse como una representación simbólica de la información, en términos generales pueden clasificarse en:
#
# * Estructurados
# * Semi estructurados
# * No estructurados
#
# Existen diversas formas de almacenar los datos

# %%
Image("local/imgs/nosql.png")

# %% [markdown]
# Las bases de datos NoSQL son ampliamente utilizadas en sistemas de Big Data entre otros factores debido al rendimiento que proporcionan y a la posibilidad de distribuir los datos

# %% [markdown]
# #**Aplicaciones**
#
# Big Data se puede aplicar a cualquier área en la que se disponga de grandes volúmenes de datos generados a gran velocidad y con variedad de los mismos (representados en diferentes formatos)

# %% [markdown]
# Los siguientes enlaces presentan aplicaciones reales de Big Data en distintas áreas como deporte, política y entretenimiento
#
# https://www.youtube.com/watch?v=-4R3m4ybDz4
#
# https://www.youtube.com/watch?v=DXq30dvE0Xg
#
# https://www.youtube.com/watch?v=EKmWMjvWFPg
#
# https://www.youtube.com/watch?v=ku78zo9fhoI
#
# https://www.dw.com/es/predecir-el-futuro-con-el-big-data/av-17816690
#
# https://www.estrategiasdeinversion.com/analisis/bolsa-y-mercados/el-experto-opina/el-big-data-nos-ayuda-a-predecir-el-comportamiento-n-323203
#
# https://www.youtube.com/watch?v=fO7G6gRFLLM
#
# https://www.youtube.com/watch?v=ImN4FTarqfo&t=53s
#
# https://www.youtube.com/watch?time_continue=162&v=s6-jmMNioes
