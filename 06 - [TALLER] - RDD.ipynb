# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/UDEA-Esp-Analitica-y-Ciencia-de-Datos/EACD-03-BIGDATA/master/init.py
import init; init.init(force_download=False); 
from IPython.display import Image

# %%
Image("local/imgs/udea-datascience.png")

# %% [markdown]
# # **TALLER 2: RDD**
# ## Desarrollado por: Mg. Efraín Alberto Oviedo
# ## Universidad de Antioquia

# %% [markdown]
# Por favor, ingrese la siguiente información:
#
# **Nombre Completo:**
#
# **Cédula:**
#
# **Correo Institucional:**

# %% [markdown]
# #**Análisis de suicidio en Caldas**
#
# La dirección territorial de salud de Caldas ha recolectado la información relacionada con los suicidios ocurridos en el departamento desde el año 2010 hasta el año 2016 (Disponible en https://www.datos.gov.co)
#
# Para cada caso se ha recolectado la siguiente información:
#
# * Sitio de defunción
# * Año
# * Mes
# * Hora
# * Sexo
# * Estado civil
# * Edad
# * Municipio
# * Nivel de educación
# * Ocupación
# * Descripción
#
# Se solicita de su ayuda para responder a los siguientes interrogantes

# %% [markdown]
# ##**A) Calidad de datos**
#
# Revise cada una de las variables disponibles y elimine del dataset todos los registros que considere atípicos, justificando las razones de su decisión

# %% [markdown]
# Presente aquí el código desarrollado y el resultado obtenido

# %% [markdown]
# ##**B) Aumento de casos de defunción en el hogar**
#
# Identifique si los casos de defunción en el hogar se han incrementado con los años

# %% [markdown]
# Presente aquí el código desarrollado y el resultado obtenido

# %% [markdown]
# ##**C) Qué pasa en la capital**
#
# Calcule el promedio de edad por sexo para los suicidios presentados en la capital

# %% [markdown]
# Presente aquí el código desarrollado y el resultado obtenido

# %% [markdown]
# ##**D) Qué papel juega el nivel de educación y el estado civil**
#
# Se desea conocer la importancia del nivel de educación en las mujeres según su edad.
# Algunos dicen que después de los 30 años pueden aumentar los casos de suicidio para las mujeres cuando se tiene nivel de educación bajo. Plantee una consulta que permita revisar esa hipótesis
#
# Otra creencia es qué en las mismas condiciones, mujeres mayores de 30 años, el estado civil empeora la situación. Plantee una consulta al respecto y presente sus conclusiones comparando las dos variables en cuestión

# %% [markdown]
# Presente aquí el código desarrollado y el resultado obtenido

# %% [markdown]
# ##**E) Qué podemos concluir a partir de la descripción**
#
# Se dispone de un campo de descripción que no emplea un formato claro que permita analizar los casos de suicidio.
#
# Plantee una forma de analizar esta información para conocer las formas de suicidio más comunes

# %% [markdown]
# Presente aquí el código desarrollado y el resultado obtenido
